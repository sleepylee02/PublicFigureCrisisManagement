# %%
import pandas as pd
import re
import os
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

# API Key and YouTube API Configuration
API_KEY = "api_key"  # Replace with your actual API key
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# Build the YouTube API client
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

def get_video_transcript(video_id, language="ko"):
    """
    Fetch transcript for a given video ID in the specified language (default: Korean).
    """
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=[language])
        return [entry["text"] for entry in transcript]
    except TranscriptsDisabled:
        print(f"Transcript is disabled for video ID: {video_id}")
        return None  # Indicate no transcript available
    except NoTranscriptFound:
        print(f"No transcript found for language '{language}' for video ID: {video_id}")
        return None  # Indicate no transcript available
    except Exception as e:
        print(f"Transcript error for video ID {video_id}: {e}")
        return None


def search_videos_with_transcripts(query, published_after, published_before, max_results=10, order="viewCount"):
    """
    Search YouTube for videos by query and date range, ensuring each video has a transcript.
    """
    request = youtube.search().list(
        part="snippet",
        q=query,
        type="video",
        maxResults=50,  # Fetch more videos to ensure we can filter for transcripts
        order=order,
        publishedAfter=published_after,
        publishedBefore=published_before
    )
    response = request.execute()

    videos = []
    for item in response.get("items", []):
        video_id = item["id"]["videoId"]
        title = item["snippet"]["title"]
        publish_date = item["snippet"]["publishedAt"]

        # Check for transcript availability
        transcript = get_video_transcript(video_id, language="ko")
        if transcript:
            videos.append({
                "video_id": video_id,
                "title": title,
                "publish_date": publish_date,
                "transcript": transcript  # Save the transcript here for optimization
            })

        # Stop when we have enough videos with transcripts
        if len(videos) >= max_results:
            break

    if not videos:
        print("No videos with transcripts found.")
    return videos


def get_video_details_with_comments(video_id):
    """
    Get video details including views, likes, and up to 1000 comments.
    """
    # Fetch video details
    video_request = youtube.videos().list(
        part="statistics,snippet",
        id=video_id
    )
    video_response = video_request.execute()

    # Extract video details
    video_data = video_response["items"][0]
    details = {
        "views": int(video_data["statistics"].get("viewCount", "0")),
        "likes": video_data["statistics"].get("likeCount", "N/A"),
        "comments_count": video_data["statistics"].get("commentCount", "N/A"),
    }

    # Fetch up to 1000 comments
    comments = []
    next_page_token = None

    while len(comments) < 1000:
        try:
            comment_request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50,  # Maximum allowed per request
                pageToken=next_page_token,
                order="relevance"
            )
            comment_response = comment_request.execute()
            for comment_item in comment_response.get("items", []):
                top_comment = comment_item["snippet"]["topLevelComment"]["snippet"]
                comments.append({
                    "comment_text": top_comment["textDisplay"],
                    "comment_likes": int(top_comment["likeCount"]),
                    "comment_date" : top_comment["publishedAt"]
                })
            next_page_token = comment_response.get("nextPageToken")
            if not next_page_token:  # Stop if there are no more pages
                break
        except Exception as e:
            print(f"Error fetching comments for video ID {video_id}: {e}")
            break

    # Sort comments by likes in descending order
    sorted_comments = sorted(comments, key=lambda x: x["comment_likes"], reverse=True)
    details["comments"] = sorted_comments[:1000]  # Limit to 1000 comments

    return details

# %%
def fetch_videos_and_save(query, published_after, published_before, max_results):
    """
    Fetch videos and save details, comments, and transcripts to a CSV file.
    
    Parameters:
    - query: Search query string
    - published_after: Start date for video search
    - published_before: End date for video search
    - max_results: Maximum number of videos to fetch
    """
    # Search videos with transcripts
    videos = search_videos_with_transcripts(
        query=query,
        published_after=published_after,
        published_before=published_before,
        max_results=max_results,
        order="viewCount"
    )

    # Enrich videos with details (comments, views, etc.)
    video_details = []
    for video in videos:
        # Fetch detailed video data (views, likes, comments)
        detailed_data = get_video_details_with_comments(video["video_id"])

        # Merge the data from search_videos_with_transcripts with get_video_details_with_comments
        details = {
            "title": video["title"],
            "publish_date": video["publish_date"],
            "video_id": video["video_id"],
            "transcript": video["transcript"],  # Keep the transcript
            **detailed_data  # Include detailed data (views, likes, comments)
        }

        video_details.append(details)

    # Sort videos by views in descending order
    video_details.sort(key=lambda x: x["views"], reverse=True)

    # Prepare data for DataFrame
    data_transcript = []

    df_comment = pd.DataFrame()

    for details in video_details:
        label_comment = [] 
        filtered_comments = [comment for comment in details["comments"] if comment["comment_likes"] > 10]
        for _ in range(len(filtered_comments)):
            label_comment.append(details["video_id"])
        
        data_comment = (pd.DataFrame({
            "Video_ID" : label_comment,
            "comment_text" : [comment["comment_text"] for comment in filtered_comments],
            "comment_likes" : [comment["comment_likes"] for comment in filtered_comments],
            "comment_date" : [comment["comment_date"] for comment in filtered_comments]
        }))

        df_comment = pd.concat([df_comment, data_comment], ignore_index=True)

        transcript_text = "|".join(details["transcript"]) if isinstance(details["transcript"], list) else details["transcript"]

        # Append to data
        data_transcript.append({
            "Title": details["title"],
            "Video_ID": details["video_id"],
            "Publish Date": details["publish_date"],
            "Views": details["views"],
            "Likes": details["likes"],
            "Comments_Count": details["comments_count"],
            "Transcript": transcript_text
        })

    # Create DataFrame
    df_transcript = pd.DataFrame(data_transcript)

    # Save to CSV
    transcript_file = f"{query}_youtube_transcript_{published_after}_to_{published_before}.csv"
    comment_file = f"{query}_youtube_comment_{published_after}_to_{published_before}.csv"
    df_transcript.to_csv(transcript_file, index=False, encoding="utf-8-sig")
    df_comment.to_csv(comment_file, index=False, encoding="utf-8-sig")

    print(f"Data saved to {df_transcript}")
    print(f"Data saved to {df_comment}")

# %%
# Define time periods
time_periods = [
    {"published_after": "2018-10-19T00:00:00Z", "published_before": "2020-10-19T23:59:59Z"},
    {"published_after": "2020-10-20T00:00:00Z", "published_before": "2020-10-21T23:59:59Z"},
    {"published_after": "2020-10-22T00:00:00Z", "published_before": "2020-12-22T23:59:59Z"}
]

# Iterate through time periods and fetch videos
query = "아이린"
max_results = 10

for period in time_periods:
    fetch_videos_and_save(
        query=query,
        published_after=period["published_after"],
        published_before=period["published_before"],
        max_results=max_results
    )
# Out:
# Transcript is disabled for video ID: 0OJ4aTCrGyE
# Transcript is disabled for video ID: wCWoUUWwdqg
# Transcript is disabled for video ID: uVXu2McmpYs
# No transcript found for language 'ko' for video ID: PHp3wWbR9cw
# Transcript is disabled for video ID: 3tYJTkdQMgA
# Transcript is disabled for video ID: 9UD0MSOE3X0
# No transcript found for language 'ko' for video ID: ChhCpSVrjvU
# No transcript found for language 'ko' for video ID: o91OUaj4gm8
# No transcript found for language 'ko' for video ID: noK5jMN9UmA
# Transcript is disabled for video ID: bHreEWWGGZ8
# No transcript found for language 'ko' for video ID: 7CV25uBj2bw
# No transcript found for language 'ko' for video ID: zasD3mYNSsU
# No transcript found for language 'ko' for video ID: a39GyyirOkg
# No transcript found for language 'ko' for video ID: YQVuin19bLg
# No transcript found for language 'ko' for video ID: gLgJe2yzStU
# No transcript found for language 'ko' for video ID: QfCSlz3dRDI
# No transcript found for language 'ko' for video ID: KfpUkFSJwLs
# Transcript is disabled for video ID: CSBZrcH7pKE
# Transcript is disabled for video ID: FeyLWT3yfoE
# Transcript is disabled for video ID: -Pp4M5dhkKc
# Transcript is disabled for video ID: rAiBmrWz6C4
# No transcript found for language 'ko' for video ID: F5yg9NTzNx8
# Transcript is disabled for video ID: Tq4BBVMnG00
# No transcript found for language 'ko' for video ID: 0DvUWRTNGWI
# No transcript found for language 'ko' for video ID: YdfEyGS5PgA
# Transcript is disabled for video ID: eyFz-vDe2mA
# Error fetching comments for video ID lDJ89x2w-K4: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=lDJ89x2w-K4&maxResults=50&order=relevance&key=AIzaSyCRWrHlVbou2igBVzDuMOdG6y_3vGX75RY&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Error fetching comments for video ID tP7S34Cgnr0: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=tP7S34Cgnr0&maxResults=50&order=relevance&key=AIzaSyCRWrHlVbou2igBVzDuMOdG6y_3vGX75RY&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Data saved to                                                Title     Video_ID  \
# 0  Red Velvet - IRENE &amp; SEULGI &#39;Monster&#...  Ujb-gvqsoi0
# 1                    아이린 IRENE is effortlessly funny  vP2JRvncjfY
# 2  레드벨벳 아이컨택캠 (EYE CONTACT🎥) S2 EP5. &#39;아이린의 소확...  kpsuuAAaG48
# 3  [마이보그] 유튜브 새내기 아이린! 갈 곳을 잃은 손💦( 왓츠인마이백,지갑,가방,립...  lDJ89x2w-K4
# 4  카메라에 잡힌 본인 모습을 본 아이린 Irene reaction, see herse...  DExqdVP5Fcw
# 5  [문명특급 EP.131] (ENG) &quot;걍 쳐다보면 죽던데?&quot; 아이...  tP7S34Cgnr0
# 6                     G마켓 잘됨파티 캠페인 ‘고백편’ (feat. 아이린)  21MaqIDzSg0
# 7  [방구석 여기서요?] Red Velvet (IRENE &amp; SEULGI...  HvpLHHO620Y
# 8  [댓글 모아주는 편집자 #5] 이게 비즈니스라면 박보검과 아이린은 일에 미쳐버린 게...  D3zuSu4EBD4
# 9                  민낯도 문제없는 아이린의 얼탁 ‘저장각’ @가로채널 EP14  iVX6zoM4ByQ
#
#            Publish Date      Views    Likes Comments_Count  \
# 0  2020-07-07T03:00:05Z  141237278  3846213         267142
# 1  2019-12-13T09:59:26Z    6434524   171128           3175
# 2  2018-12-23T03:00:04Z    5594187   148780           7458
# 3  2020-09-23T11:00:12Z    4375116   128239            N/A
# 4  2019-01-30T05:44:23Z    4188599    47879            972
# 5  2020-07-20T08:00:09Z    3618379    80994            N/A
# 6  2019-11-25T06:58:54Z    3313950     6732            844
# 7  2020-07-15T07:00:03Z    2863750    99206           1682
# 8  2020-08-15T01:00:13Z    2819987    38820           3597
# 9  2019-02-14T15:31:11Z    2817101    31646           1793
#
#                                           Transcript
# 0  내 움직임은 특이해 평범치 않아|1 2 5 to 7 난 어둠 속의 Dancer|온몸...
# 1  or|아|아|뭐야|[음악]|[박수]|[음악]|으|예|er|[박수]|처음에는 약간 롱...
# 2  전을|아 비 차를 놓쳤어요|yeah 엄청|여걸 장에서 아시오|[음악]|알리지 언니가...
# 3  [이 영상은 브랜드 협찬으로 제작되었습니다]\n어떻게 하는 거야?|여긴가?|안녕하세...
# 4  on|[박수]|er|we|we|you|you|아아아|아 wm 왜냐 아|[박수]|아 ...
# 5  그냥 쳐다보면 다 죽는구나?|죽던데? 여기다 한 번.|그냥 쳐다보면 죽던데?|그냥 ...
# 6  치 마켓 영화 티켓 좋아하죠|마브 줘 이렇게 따져 해야 안 할 수 있죠|빨아 농기계...
# 7  아 아 아|아|아|who|예|에|에 몰살을|했구요 어 저희가 중력식 시작하죠|절마다...
# 8  아 co|the 아 아 왔을 때 다른 길로 아아아아 아 아아아아 생각했는데|[음악]...
# 9  [음악]|5|[음악]|냄새부터 표지 관리하세요 아|아 마울 빨라 본데요 마 아|굉장...
# Data saved to          Video_ID                                       comment_text  \
# 0     Ujb-gvqsoi0  FINALLY the monsters at SM released Monster! N...
# 1     Ujb-gvqsoi0  the only straight thing in this mv is seulgi&#...
# 2     Ujb-gvqsoi0  Seulrene: “I’m a little monster”<br>Me: <b>loo...
# 3     Ujb-gvqsoi0  Red velvet are getting more darker now. No mor...
# 4     Ujb-gvqsoi0  when their hairstyles are straight but the who...
# ...           ...                                                ...
# 2011  iVX6zoM4ByQ                                          강약 중강약 약강
# 2012  iVX6zoM4ByQ                                            ㅋㅋㅋㅋ귀여왕
# 2013  iVX6zoM4ByQ                 ㄹㅇ잘 몰라서 그러는뒈~이분이 공포증 탈부착 가능하시다는 분?
# 2014  iVX6zoM4ByQ                        민낯은 문제없지만 인성엔 문제가 있었다̐̈ …^^
# 2015  iVX6zoM4ByQ                            민낯도 문제 없었지만 인성은 문제가 있었다
#
#       comment_likes          comment_date
# 0           30470.0  2020-07-07T03:00:25Z
# 1           27196.0  2020-07-07T21:08:27Z
# 2           15042.0  2020-07-07T04:31:34Z
# 3           13305.0  2020-08-08T07:21:10Z
# 4           12855.0  2020-07-10T02:23:25Z
# ...             ...                   ...
# 2011           11.0  2020-10-24T02:31:08Z
# 2012           11.0  2020-04-24T03:56:43Z
# 2013           11.0  2020-12-06T09:41:49Z
# 2014           11.0  2020-11-30T16:46:20Z
# 2015           11.0  2020-11-29T10:10:02Z
#
# [2016 rows x 4 columns]
# Transcript is disabled for video ID: hZAFYZqVRto
# Transcript is disabled for video ID: GaJxlDkyHz4
# No transcript found for language 'ko' for video ID: HqrN7Bbq5_Y
# No transcript found for language 'ko' for video ID: _tcQZmBf7IE
# No transcript found for language 'ko' for video ID: I_c8aE1RVMM
# 8  2020-10-23T23:00:03Z   758931   3116           1063
# 9  2020-10-23T06:46:35Z   656119   6046           2416
#
#                                           Transcript
# 0  이렇게 그러면 저도 표정 묘사가 그런거 아냐 이 것인지|outer 가지는 같은 굉장...
# 1  2014년에 대비하여 덤덤 빨간 맛 피카부 등등의 수많은 히트곡을|탄생시키며 인기를...
# 2  아이린의 갑질 폭로가 이어진 후에 아이는 옹호하는 글도 업로드 되었는데요|ie 는 ...
# 3  으|[음악]|현재 연 이 판은 실시간 검색어가 아이린 으로 모두 도배가 되었는데요|...
# 4  [음악]|아 1인과 웬디가 함께 서서 사진을 찍는 듯 보이는데요 인사를 하던 웬디|...
# 5  빛이 내린다 트위 음|언니를 이렇게 그렇게 보면 되게 차갑고|그렇게 느꼈어 그래서 ...
# 6  [음악]|멤버들과 함께 과제를 먹던 아이린이 스태프에게 과제를 주는 모습인데요|이를...
# 7  [음악]|쓰기가 커다란 큐브를 들고 오는데요|촬영 때는 아이린이 튜브 를 사용하네요...
# 8  현재 아이린 인성 및 각질 논란이 화제가 되고 있는데요 어깨 관계자들의|폭로가 줄줄...
# 9  [음악]|으|그룹 레드 벨벳 아이린 갑질 폭로 글을 게재한 에디터 a 씨의 그래|동...
# Data saved to          Video_ID                                       comment_text  \
# 0     _Km-X6d1E-U  50%는 재량으로 표현할 수 있지만<br>다른 50%는 원판을 감안하고 봐달라는 것...
# 1     _Km-X6d1E-U                          저런 포인트를 도대체 어떻게 잡는거지 ㅋㅋㅋㅋ
# 2     _Km-X6d1E-U                     역시 표정묘사 하면 우리 씅 ㅋㅋㅋㅋㅋ<br>잘해 잘해
# 3     _Km-X6d1E-U   근데 승희 앞머리도 아니고 뒷머리가 왜케 잔디같이 삐죽삐죽한거에욬ㅋㅋㅋㅋㅋㅋ 병아리같다
# 4     _Km-X6d1E-U  왜 아무도 효정언니 웃음소리 얘기 안 해 ㅋㅋㅋㅋㅋㅅㅋ 거의 뭐 장난감 원숭이 인형...
# ...           ...                                                ...
# 1209  VNi4c27SMJ0                   sm엠이 아이돌은 잘키우는데 애들인성은 어떻게할수가없나봄.
# 1210  VNi4c27SMJ0  사람의 말..곧 그 사람의 인성(격)은 사향가루와도 같아서...<br>주머니 속에 ...
# 1211  VNi4c27SMJ0  난 진짜 애 이쁘다 이쁘다 하도 해서 이쁜가 보다 했었는데.. 내 눈엔 안 이뻐 보...
# 1212  VNi4c27SMJ0                                        와..아니..실망..
# 1213  VNi4c27SMJ0  사람 고쳐쓰는거 아니다, 사람은 바뀌지 않는다라는 말은 괜히 하는 말이 아니죠.<b...
#
#       comment_likes          comment_date
# 0              7451  2020-12-22T06:42:11Z
# 1              6342  2020-12-16T04:46:46Z
# 2              6193  2020-12-16T04:53:22Z
# 3              2602  2020-12-20T08:36:33Z
# 4              1047  2020-12-20T01:27:04Z
# ...             ...                   ...
# 1209             12  2021-06-08T01:21:36Z
# 1210             12  2020-10-24T14:20:59Z
# 1211             12  2020-10-23T11:20:21Z
# 1212             12  2020-10-23T07:01:37Z
# 1213             11  2020-10-28T13:59:41Z
#
# [1214 rows x 4 columns]

# %%
# Define time periods
time_periods = [
    {"published_after": "2012-12-04T00:00:00Z", "published_before": "2014-12-04T23:59:59Z"},
    {"published_after": "2014-12-05T00:00:00Z", "published_before": "2014-12-07T23:59:59Z"},
    {"published_after": "2014-12-08T00:00:00Z", "published_before": "2015-01-08T23:59:59Z"}
]

# Iterate through time periods and fetch videos
query = "조현아"
max_results = 10

for period in time_periods:
    fetch_videos_and_save(
        query=query,
        published_after=period["published_after"],
        published_before=period["published_before"],
        max_results=max_results
    )
# Out:
# No transcript found for language 'ko' for video ID: -PKsgTvtIzg
# No transcript found for language 'ko' for video ID: fwUgWQ6cqjY
# Transcript is disabled for video ID: YtgkWnZRurE
# No transcript found for language 'ko' for video ID: cssrX7UtuII
# Transcript is disabled for video ID: XvsrR_MmZfo
# Transcript is disabled for video ID: lhNCwHhwXCU
# No transcript found for language 'ko' for video ID: 9Cn40uBP17I
# Data saved to                                                Title     Video_ID  \
# 0             [M/V] 너는 나를 (feat. 조현아 of 어반자카파) - 김진표  XIxm1rt1rks
# 1                                     River - 어반 자카파  1XQGoi5zWIM
# 2  크루시픽스 크릭 Reunion (feat. The Quiett. Verbal Jin...  OUtrbc7oids
# 3      [13.09.18] 어반자카파 조현아 - 사랑이 제일 낫더라 @봄여름가을겨울의 숲  FZrvYHw427Y
# 4                                 조현아—사는게 아니야 （2013）  InuQB6gacAo
# 5  131003 Block.B SHOWCASE - (박경 Solo) 언제 어디서 무엇을...  QhbTh-_pvgc
# 6  [MV] Kim jo han(김조한) _ The stars, The moon, Al...  8TfVWKFclfQ
# 7                어반자카파(Urban Zakapa) - 커피를 마시고.고화질HQ  P-kmjsm_AB8
# 8                     조현민, 모델 제의 받은 사연 @좋은 아침 141014  KnUE6yGR0Fg
# 9                    [한영애의 숲 NoCut] 한영애 박주원 조현아 - 루씰  K6_GA1-vAMk
#
#            Publish Date   Views Likes Comments_Count  \
# 0  2013-04-01T02:29:08Z  994998  3435            367
# 1  2013-05-28T02:52:13Z  656247  1624             96
# 2  2013-08-28T00:55:17Z  372304  3629            170
# 3  2013-09-30T08:59:13Z  206311  1115             57
# 4  2013-03-29T06:48:48Z  163839   408             45
# 5  2013-10-03T11:17:25Z  161647  1447            118
# 6  2013-11-01T03:00:00Z  143690  1724             78
# 7  2013-01-18T14:01:24Z   93790   446             52
# 8  2014-10-14T02:31:35Z   67790   126            147
# 9  2013-06-14T08:52:37Z   42681   240             20
#
#                                           Transcript
# 0  [음악]|[박수]|[음악]|너를 처음 만났을 때 모든게 멈춰버린|위에 들리던 소리 ...
# 1  [음악]|참만이|울었죠 그대마음|라요 어제도|그대 울|생각게 많이|[음악]|염려했다...
# 2  [음악]|너도 가끔은 날 생각을 했었니 서로서|있는 곳은 달라도 어릴 때 함께|다니...
# 3  저 같이 한번 조현아 씨랑네 노래를|한번|들어볼까요 사랑이 제일|[음악]|낫더라|니...
# 4  [음악]|사랑하면 안 돼요|다가가면 안 돼요 왜 사랑하면|[음악]|멀어지나요 한|발...
# 5  지닝|[음악]|대신가|좋가 머리|들 그 목소리 내|엑|예 더럽혀진 좋은 신경 쓰지 ...
# 6  [음악]|[음악]|저불 일어나고 부드럽게 흐르는|멜로디|좀 더 두근거리기 위해 준비...
# 7  괜찮아 네가 없는 나도|괜찮아 가끔씩 생각나는 날도|괜찮아 사실은|아직도 실감이 안...
# 8  이 자리에 초청해 주셔서 너무|감사하고요 어 여러분 어 우리 두|MC 분들 만나뵙 ...
# 9  [음악]|[음악]|예 풀밭 같은 너의 소리는|[음악]|때론|아픔으로 때론 평화의|[...
# Data saved to         Video_ID                                       comment_text  \
# 0    XIxm1rt1rks  이노래 가사의 의미를 이해할 사람이 있을까 싶은데, 뭔가 경험하지 않고선 쓸쑤없을것...
# 1    XIxm1rt1rks                                            노래에비해안뜸
# 2    XIxm1rt1rks                  김진표 랩은 피쳐링해주는 가수들이랑 조화가 너무 좋은듯...
# 3    XIxm1rt1rks        2021) 아직도 듣는사람 있나 진짜 내 최애곡.. 가사가 공감되서 더 슬프다
# 4    XIxm1rt1rks                                           메탈에테몬 같네
# ..           ...                                                ...
# 141  KnUE6yGR0Fg                             어케 저렇게 생겨서 무슨 모델제의래 ㅋㅋ
# 142  KnUE6yGR0Fg                        방송에선 순해보이는데...실제와 방송은 다른가보네
# 143  K6_GA1-vAMk                                  한영애의 필은 진짜다..<br>
# 144  K6_GA1-vAMk  조현아님 노래듣고 와....잘한다 하다가 한영애님 노래들으니 그냥 생각이 없어짐 ....
# 145  K6_GA1-vAMk  현아씨 노래에 빠지셨다고 칭찬해 주시지만.. <br>당신의 목소리는 정말 푹 빠지게...
#
#      comment_likes          comment_date
# 0              285  2020-03-24T09:25:03Z
# 1              209  2016-10-21T20:32:03Z
# 2              172  2018-09-22T17:12:06Z
# 3              150  2021-04-24T15:49:43Z
# 4              139  2016-11-12T02:34:29Z
# ..             ...                   ...
# 141             12  2022-03-20T15:18:15Z
# 142             12  2021-08-02T11:17:16Z
# 143             21  2014-02-28T09:27:38Z
# 144             19  2014-06-11T03:34:03Z
# 145             12  2013-12-05T08:09:14Z
#
# [146 rows x 4 columns]
# No videos with transcripts found.
# Data saved to Empty DataFrame
# Columns: []
# Index: []
# Data saved to Empty DataFrame
# Columns: []
# Index: []
# Transcript is disabled for video ID: nj0Nu0tjqzc
# No transcript found for language 'ko' for video ID: XKmezv-VIYQ
# Transcript is disabled for video ID: yuAKzAgFK1s
# Error fetching comments for video ID 6nqO86JKVzk: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=6nqO86JKVzk&maxResults=50&order=relevance&key=AIzaSyCRWrHlVbou2igBVzDuMOdG6y_3vGX75RY&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Data saved to                                                Title     Video_ID  \
# 0  [MV] 2LSON _ The End(끝) (Feat. Jo Hyun Ah(조현아)...  DZzop32L700
# 1  조현아(Cho Hyun-ah) 등 &#39;한진 3세&#39; 부적절한 언행들 / ...  RPPZAqn1O0I
# 2              까도 까도 나오는 조현아 &#39;안하무인&#39; 일화 / YTN  Kp_AxtXABqs
# 3        조현아 &#39;혼거실&#39;에...조양호 &#39;울컥&#39; / YTN  Zpw88qc3Rm0
# 4  조현아 &#39;갑질&#39;…&quot;활주로 리턴 거의 없는 일&quot; / YTN  DT_AsqXMXHg
# 5                 [단독] ‘땅콩 회항’ 사무장 “욕설에 폭행…무릎까지 꿇었다”  7M2tUOxm1mc
# 6  [NocutView] &#39;땅콩 리턴&#39; 총정리…조현아는 &#39;무늬만 ...  Ocz9gn809wE
# 7             &#39;땅콩 회항&#39; 당시 일등석 승객 증언 보니… / YTN  0rU-RxZ-YdI
# 8                      [대한항공] 조현아 사과, 메뉴얼대로 척척  6nqO86JKVzk
# 9  &#39;땅콩회항&#39; 조현아 구속, &#39;재벌 3세 봐주기 없다&#39; ...  bRJuq1SI6rc
#
#            Publish Date   Views Likes Comments_Count  \
# 0  2014-12-19T03:00:02Z  627946  4177            102
# 1  2014-12-09T01:20:59Z  430087   365            164
# 2  2014-12-16T09:51:33Z  273525   515            148
# 3  2015-01-06T09:59:49Z  221713   289            109
# 4  2014-12-08T01:47:54Z  178283   203             71
# 5  2014-12-12T13:25:51Z  158443   419             46
# 6  2014-12-10T02:13:29Z  138548   188             70
# 7  2014-12-13T19:18:21Z  106354   275             50
# 8  2014-12-13T07:50:09Z  105231   173            N/A
# 9  2014-12-31T10:06:04Z   92780   140             72
#
#                                           Transcript
# 0  [음악]|해피 엔딩은 없었어 우의|한 당연한|결말일까|많은 시도로 아 know 돌려...
# 1  제 뒤로 인물 사진 보이시죠.|바로 어제 인터넷을 뜨겁게 달궜\n던 조현아 대한항공...
# 2  네 오늘 신문 보셨다면 일면 하단에|난이 광고 보셨을 겁니다 저도 지금|들고 있는데...
# 3  이 고개를 푹 수인 채 검찰을 나은|조연아 대한항공 전부사장 화려한|재벌과 3사에서...
# 4  이륙을 위해 항공기는 이미 활주로\n로 가고 있었습니다.|그런데 다시 탑승 게이트로...
# 5  이제부터는 이른바 땅콩 회항 관련|소식들 전해드립니다 먼저 저희 KBS|재진이 당시...
# 6  [음악]|Ye Ah|[음악]|이번 사건 핵심은 승계 그 자격으로|탑승한 회사 임원이...
# 7  이른바 땅콩 회양 당시 조현아 전|대한항공 부사장과 유일하게 1등석에|함께 탔던 승...
# 8  아|자 그러면 준비가 된 걸로 알고 복을|드리겠습니다 그다음에 그게 끝나면|제가 자...
# 9  네 조연화 대한항공 부사장이 어제|결국 구속됐습니다 땅콩 회양 사건|발생 25일 만...
# Data saved to        Video_ID                                       comment_text  \
# 0   DZzop32L700                            ㄹㅇ 띵곡인데 아무도 안들어서 속상....
# 1   DZzop32L700  Been awhile since the last time Giriboy took o...
# 2   DZzop32L700  Am i the only one who cant keep her eyes off t...
# 3   DZzop32L700  This song it&#39;s awesome!!!! Love the voices...
# 4   DZzop32L700  So unfortunate that the masses of internationa...
# 5   Kp_AxtXABqs                           조양호 회장은  대한항공에서 퇴출해야합니다.
# 6   Kp_AxtXABqs                                       정신과치료가필요한인물임
# 7   Kp_AxtXABqs  오십을 바라보는 딸이 마치 미성년자가 저지른 죄인양.<br>부가 사죄하는 나라는 세...
